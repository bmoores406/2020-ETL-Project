# %%
#import dependencies
import pandas as pd
import pymongo
import json
import regex

# %%
# Read Thanksgivng poll data
csv_file = "Resources/thanksgiving-2015-poll-data.csv"
Thanksgiving_data_df = pd.read_csv(csv_file)
Thanksgiving_data_df.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
# 3                                  Baked
# 4                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# 1                                        Bread-based
# 2                                         Rice-based
# 3                                        Bread-based
# 4                                        Bread-based
#
#   What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What type of cranberry saucedo you typically have?  \
# 0                                               None
# 1                             Other (please specify)
# 2                                           Homemade
# 3                                           Homemade
# 4                                             Canned
#
#   What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                    Homemade cranberry gelatin ring
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Have you ever attended a "Friendsgiving?"  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                        No
# 4                                        No
#
#   Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                     No                                              NaN
# 1                     No                                              NaN
# 2                     No                                              NaN
# 3                     No                                              NaN
# 4                     No                                              NaN
#
#   How would you describe where you live?      Age What is your gender?  \
# 0                               Suburban  18 - 29                 Male
# 1                                  Rural  18 - 29               Female
# 2                               Suburban  18 - 29                 Male
# 3                                  Urban  30 - 44                 Male
# 4                                  Urban  30 - 44                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                 $75,000 to $99,999
# 1                                 $50,000 to $74,999
# 2                                       $0 to $9,999
# 3                                    $200,000 and up
# 4                               $100,000 to $124,999
#
#             US Region
# 0     Middle Atlantic
# 1  East South Central
# 2            Mountain
# 3             Pacific
# 4             Pacific
#
# [5 rows x 65 columns]

# %%
# Rename columns to shorten the name on dish name to be used
renamed_df = Thanksgiving_data_df.rename(columns={'What is typically the main dish at your Thanksgiving dinner?':'Main Dish',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts':'Brussel sprouts',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots':'Carrots',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower':'Cauliflower',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Corn':'Corn',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cornbread':'Cornbread',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Green beans/green bean casserole':'Green beans',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Macaroni and cheese':'Macaroni and cheese',
                                  'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Mashed potatoes':'Mashed potatoes',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple':'Apple',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Cherry':'Cherry',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Chocolate':'Chocolate',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Coconut cream':'Coconut cream',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Key lime':'Key lime',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Peach':'Peach',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan':'Pecan',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin':'Pumpkin',
                                  'Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Sweet Potato':'Sweet Potato',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Apple cobbler':'Apple Cobbler',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Blondies':'Blondies',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Brownies':'Brownies',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Carrot cake':'Carrot cake',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cheesecake':'Cheesecake',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Cookies':'Cookies',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Fudge':'Fudge',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Ice cream':'Ice cream',
                                  'Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Peach cobbler':'Peach cobbler'})
renamed_df.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving? Main Dish  \
# 0    4337954960                            Yes    Turkey
# 1    4337951949                            Yes    Turkey
# 2    4337935621                            Yes    Turkey
# 3    4337933040                            Yes    Turkey
# 4    4337931983                            Yes  Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
# 2                                Roasted
# 3                                  Baked
# 4                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# 1                                        Bread-based
# 2                                         Rice-based
# 3                                        Bread-based
# 4                                        Bread-based
#
#   What kind of stuffing/dressing do you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What type of cranberry saucedo you typically have?  \
# 0                                               None
# 1                             Other (please specify)
# 2                                           Homemade
# 3                                           Homemade
# 4                                             Canned
#
#   What type of cranberry saucedo you typically have? - Other (please specify)  \
# 0                                                NaN
# 1                    Homemade cranberry gelatin ring
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Have you ever tried to meet up with hometown friends on Thanksgiving night?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Have you ever attended a "Friendsgiving?"  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                        No
# 4                                        No
#
#   Will you shop any Black Friday sales on Thanksgiving Day?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                 No
#
#   Do you work in retail? Will you employer make you work on Black Friday?  \
# 0                     No                                              NaN
# 1                     No                                              NaN
# 2                     No                                              NaN
# 3                     No                                              NaN
# 4                     No                                              NaN
#
#   How would you describe where you live?      Age What is your gender?  \
# 0                               Suburban  18 - 29                 Male
# 1                                  Rural  18 - 29               Female
# 2                               Suburban  18 - 29                 Male
# 3                                  Urban  30 - 44                 Male
# 4                                  Urban  30 - 44                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 0                                 $75,000 to $99,999
# 1                                 $50,000 to $74,999
# 2                                       $0 to $9,999
# 3                                    $200,000 and up
# 4                               $100,000 to $124,999
#
#             US Region
# 0     Middle Atlantic
# 1  East South Central
# 2            Mountain
# 3             Pacific
# 4             Pacific
#
# [5 rows x 65 columns]

# %%
# Select only the columns to be used
Thanksgiving_df = renamed_df[['Main Dish','Brussel sprouts','Carrots','Cauliflower','Corn','Cornbread','Green beans','Macaroni and cheese','Mashed potatoes',
                              'Apple','Cherry','Chocolate','Coconut cream','Key lime','Peach','Pecan','Pumpkin','Sweet Potato',
                              'Apple Cobbler','Blondies','Brownies','Carrot cake','Cheesecake','Cookies','Fudge','Ice cream','Peach cobbler']]
Thanksgiving_df.head()
# Out:
#   Main Dish  Brussel sprouts  Carrots  Cauliflower  Corn  Cornbread  \
# 0    Turkey              NaN  Carrots          NaN   NaN        NaN
# 1    Turkey              NaN      NaN          NaN  Corn        NaN
# 2    Turkey  Brussel sprouts  Carrots  Cauliflower  Corn  Cornbread
# 3    Turkey  Brussel sprouts      NaN          NaN   NaN  Cornbread
# 4  Tofurkey  Brussel sprouts      NaN          NaN   NaN  Cornbread
#
#                         Green beans  Macaroni and cheese  Mashed potatoes  \
# 0  Green beans/green bean casserole  Macaroni and cheese  Mashed potatoes
# 1  Green beans/green bean casserole  Macaroni and cheese  Mashed potatoes
# 2                               NaN                  NaN  Mashed potatoes
# 3                               NaN                  NaN  Mashed potatoes
# 4                               NaN                  NaN  Mashed potatoes
#
#    Apple  ...  Sweet Potato Apple Cobbler Blondies  Brownies  Carrot cake  \
# 0  Apple  ...           NaN           NaN      NaN       NaN          NaN
# 1  Apple  ...           NaN           NaN      NaN       NaN          NaN
# 2  Apple  ...  Sweet Potato           NaN      NaN  Brownies  Carrot cake
# 3    NaN  ...           NaN           NaN      NaN       NaN          NaN
# 4  Apple  ...           NaN           NaN      NaN       NaN          NaN
#
#    Cheesecake  Cookies  Fudge  Ice cream Peach cobbler
# 0  Cheesecake  Cookies    NaN  Ice cream           NaN
# 1  Cheesecake  Cookies    NaN        NaN           NaN
# 2         NaN  Cookies  Fudge  Ice cream           NaN
# 3         NaN      NaN    NaN        NaN           NaN
# 4         NaN      NaN    NaN        NaN           NaN
#
# [5 rows x 27 columns]

# %%
# List of Main Dish 
maindish_df = Thanksgiving_df[['Main Dish']].copy()
dropped_maindish_df = maindish_df.drop_duplicates()
maindish_list = dropped_maindish_df['Main Dish'].tolist()
maindish_list
# Out:
# ['Turkey',
#  'Tofurkey',
#  'Other (please specify)',
#  nan,
#  'Ham/Pork',
#  'Turducken',
#  'Roast beef',
#  'Chicken',
#  "I don't know"]

# %%
# group by, count, rename, dropping the "Other" and "I don't know" rows to get count for each Main Dish:
maindish_group = maindish_df.groupby(['Main Dish'], sort=False)
maindish_count = maindish_group['Main Dish'].count()
maindish_count = pd.DataFrame(maindish_count)
maindish_rename = maindish_count.rename(columns={'Main Dish':'Count'})
drop1 = maindish_rename.drop(index="Other (please specify)")
maindish_count_df = drop1.drop(index="I don't know")
maindish_count_df
# Out:
#             Count
# Main Dish
# Turkey        859
# Tofurkey       20
# Ham/Pork       29
# Turducken       3
# Roast beef     11
# Chicken        12

# %%
#create a list of the main dishes using the index from the dataframe:
main_list = maindish_count_df.index.tolist()
print(main_list)
# Out:
# ['Turkey', 'Tofurkey', 'Ham/Pork', 'Turducken', 'Roast beef', 'Chicken']

# %%
#create a dictionary to be loaded into a database with "Main" as the key and the above list as the values:
main_dict = {'Main': main_list}
print(main_dict)
# Out:
# {'Main': ['Turkey', 'Tofurkey', 'Ham/Pork', 'Turducken', 'Roast beef', 'Chicken']}

# %%
# Select Side Dishes
sides_df = Thanksgiving_df[['Brussel sprouts','Carrots','Cauliflower','Corn','Cornbread',
                            'Green beans','Macaroni and cheese','Mashed potatoes']]
sides_df.head()
# Out:
#    Brussel sprouts  Carrots  Cauliflower  Corn  Cornbread  \
# 0              NaN  Carrots          NaN   NaN        NaN
# 1              NaN      NaN          NaN  Corn        NaN
# 2  Brussel sprouts  Carrots  Cauliflower  Corn  Cornbread
# 3  Brussel sprouts      NaN          NaN   NaN  Cornbread
# 4  Brussel sprouts      NaN          NaN   NaN  Cornbread
#
#                         Green beans  Macaroni and cheese  Mashed potatoes
# 0  Green beans/green bean casserole  Macaroni and cheese  Mashed potatoes
# 1  Green beans/green bean casserole  Macaroni and cheese  Mashed potatoes
# 2                               NaN                  NaN  Mashed potatoes
# 3                               NaN                  NaN  Mashed potatoes
# 4                               NaN                  NaN  Mashed potatoes

# %%
# transpose and index to get list of Side Dishes
tsides_df = sides_df.T

tsides_df.index

tsides_df.head()
# Out:
#                     0     1                2                3     \
# Brussel sprouts      NaN   NaN  Brussel sprouts  Brussel sprouts
# Carrots          Carrots   NaN          Carrots              NaN
# Cauliflower          NaN   NaN      Cauliflower              NaN
# Corn                 NaN  Corn             Corn              NaN
# Cornbread            NaN   NaN        Cornbread        Cornbread
#
#                             4                5    6        7     \
# Brussel sprouts  Brussel sprouts  Brussel sprouts  NaN      NaN
# Carrots                      NaN          Carrots  NaN  Carrots
# Cauliflower                  NaN      Cauliflower  NaN      NaN
# Corn                         NaN             Corn  NaN      NaN
# Cornbread              Cornbread        Cornbread  NaN      NaN
#
#                             8                9     ...  1048       1049  1050  \
# Brussel sprouts  Brussel sprouts  Brussel sprouts  ...   NaN        NaN   NaN
# Carrots                      NaN          Carrots  ...   NaN        NaN   NaN
# Cauliflower                  NaN              NaN  ...   NaN        NaN   NaN
# Corn                        Corn              NaN  ...  Corn        NaN  Corn
# Cornbread              Cornbread              NaN  ...   NaN  Cornbread   NaN
#
#                  1051 1052 1053  1054 1055 1056  1057
# Brussel sprouts   NaN  NaN  NaN   NaN  NaN  NaN   NaN
# Carrots           NaN  NaN  NaN   NaN  NaN  NaN   NaN
# Cauliflower       NaN  NaN  NaN   NaN  NaN  NaN   NaN
# Corn             Corn  NaN  NaN  Corn  NaN  NaN  Corn
# Cornbread         NaN  NaN  NaN   NaN  NaN  NaN   NaN
#
# [5 rows x 1058 columns]

# %%
#create a list of the side dishes using the index from the dataframe:
side_list = tsides_df.index.tolist()

#create a dictionary to be loaded into a database with "Side" as the key and the above list as the values:
side_dict = {'Side':side_list}
print(side_dict)
# Out:
# {'Side': ['Brussel sprouts', 'Carrots', 'Cauliflower', 'Corn', 'Cornbread', 'Green beans', 'Macaroni and cheese', 'Mashed potatoes']}

# %%
# Select pies
pie_df = Thanksgiving_df[['Apple','Cherry','Chocolate','Coconut cream','Key lime',
                          'Peach','Pecan','Pumpkin','Sweet Potato']]
pie_df.head()
# Out:
#    Apple  Cherry  Chocolate Coconut cream Key lime  Peach  Pecan  Pumpkin  \
# 0  Apple     NaN        NaN           NaN      NaN    NaN    NaN      NaN
# 1  Apple     NaN  Chocolate           NaN      NaN    NaN    NaN  Pumpkin
# 2  Apple  Cherry        NaN           NaN      NaN  Peach  Pecan  Pumpkin
# 3    NaN     NaN        NaN           NaN      NaN    NaN  Pecan  Pumpkin
# 4  Apple     NaN        NaN           NaN      NaN    NaN    NaN  Pumpkin
#
#    Sweet Potato
# 0           NaN
# 1           NaN
# 2  Sweet Potato
# 3           NaN
# 4           NaN

# %%
# transpose and index to get list of pies
tpie_df = pie_df.T

#make the index into a list
pie_list = tpie_df.index.tolist()
print(pie_list)
# Out:
# ['Apple', 'Cherry', 'Chocolate', 'Coconut cream', 'Key lime', 'Peach', 'Pecan', 'Pumpkin', 'Sweet Potato']

# %%
#create a dictionary with key 'pie' and values of the pie_list:
pie_dict = {'Pie': pie_list}

# %%
print(pie_dict)
# Out:
# {'Pie': ['Apple', 'Cherry', 'Chocolate', 'Coconut cream', 'Key lime', 'Peach', 'Pecan', 'Pumpkin', 'Sweet Potato']}

# %%
len(pie_dict['Pie'])
# Out:
# 9

# %%
print(pie_dict['Pie'][2])
# Out:
# Chocolate

# %%
# Select desserts
dessert_df = Thanksgiving_df[['Apple Cobbler','Blondies','Brownies','Carrot cake','Cheesecake',
                              'Cookies','Fudge','Ice cream','Peach cobbler']]
dessert_df.head()
# Out:
#   Apple Cobbler Blondies  Brownies  Carrot cake  Cheesecake  Cookies  Fudge  \
# 0           NaN      NaN       NaN          NaN  Cheesecake  Cookies    NaN
# 1           NaN      NaN       NaN          NaN  Cheesecake  Cookies    NaN
# 2           NaN      NaN  Brownies  Carrot cake         NaN  Cookies  Fudge
# 3           NaN      NaN       NaN          NaN         NaN      NaN    NaN
# 4           NaN      NaN       NaN          NaN         NaN      NaN    NaN
#
#    Ice cream Peach cobbler
# 0  Ice cream           NaN
# 1        NaN           NaN
# 2  Ice cream           NaN
# 3        NaN           NaN
# 4        NaN           NaN

# %%
# transpose and index to get list of desserts
tdessert_df = dessert_df.T

#create a list of the dessert dishes using the index from the dataframe:
dessert_list = tdessert_df.index.tolist()

#create a dictionary to be loaded into a database with "Dessert" as the key and the above list as the values:
dessert_dict = {'Dessert': dessert_list}
#tdessert_df

print(dessert_dict)
# Out:
# {'Dessert': ['Apple Cobbler', 'Blondies', 'Brownies', 'Carrot cake', 'Cheesecake', 'Cookies', 'Fudge', 'Ice cream', 'Peach cobbler']}

# %%
# group by and count for any single side dish, pie, or dessert
dessert_group = dessert_df.groupby(, axis=0, sort=False)
dessert_count = dessert_group['Apple Cobbler'].count()
dessert_count
# Out:
#   File "<ipython-input-20-1d39a19d42e2>", line 2
#     dessert_group = dessert_df.groupby(, axis=0, sort=False)
#                                        ^
# SyntaxError: invalid syntax

# %%
#read in json file, adding in the "lines=True" condition as each item in the file is a separate dictionary
json_file = "Resources/recipes.json"
recipe_data_df = pd.read_json(json_file, lines=True)
recipe_data_df.head()
# Out:
#                            Name  \
# 0                 Christmas pie
# 1  Simmer-&-stir Christmas cake
# 2            Christmas cupcakes
# 3                Christmas buns
# 4            Christmas cupcakes
#
#                                                  url  \
# 0  https://www.bbcgoodfood.com/recipes/2793/chris...
# 1  https://www.bbcgoodfood.com/recipes/1160/simme...
# 2  https://www.bbcgoodfood.com/recipes/72622/chri...
# 3  https://www.bbcgoodfood.com/recipes/1803633/ch...
# 4  https://www.bbcgoodfood.com/recipes/981634/chr...
#
#                                          Description            Author  \
# 0  Combine a few key Christmas flavours here to m...      Mary Cadogan
# 1  An easy-to-make alternative to traditional Chr...      Mary Cadogan
# 2  These beautiful and classy little cakes make l...     Sara Buenfeld
# 3  Paul Hollywood's fruit rolls can be made ahead...    Paul Hollywood
# 4  Made these for the second time today, and I ha...  Barney Desmazery
#
#                                          Ingredients  \
# 0  [2 tbsp olive oil, knob butter, 1 onion, finel...
# 1  [175g butter, chopped, 200g dark muscovado sug...
# 2  [200g dark muscovado sugar, 175g butter, chopp...
# 3  [500g strong white flour, plus extra for dusti...
# 4  [280g self-raising flour, 175g golden caster s...
#
#                                               Method
# 0  [Heat oven to 190C/fan 170C/gas 5. Heat 1 tbsp...
# 1  [Put the butter, sugar, fruit, zests, juice an...
# 2  [Tip the sugar, butter, dried fruit, whole che...
# 3  [Put the flour and 1 tsp salt into a large bow...
# 4  [Heat oven to 190C/170 fan/gas 5 and line a 12...

# %%
#create a new dataframe with only the Name, url, and Ingredients columns:
filtered_recipe_df = recipe_data_df[['Name','url','Ingredients']]
filtered_recipe_df
# Out:
#                               Name  \
# 0                    Christmas pie
# 1     Simmer-&-stir Christmas cake
# 2               Christmas cupcakes
# 3                   Christmas buns
# 4               Christmas cupcakes
# ...                            ...
# 1612             Flavoured butters
# 1613             Crispy Roast Duck
# 1614        Smoked salmon kedgeree
# 1615             Spicy potted crab
# 1616          Sage and Onion Sauce
#
#                                                     url  \
# 0     https://www.bbcgoodfood.com/recipes/2793/chris...
# 1     https://www.bbcgoodfood.com/recipes/1160/simme...
# 2     https://www.bbcgoodfood.com/recipes/72622/chri...
# 3     https://www.bbcgoodfood.com/recipes/1803633/ch...
# 4     https://www.bbcgoodfood.com/recipes/981634/chr...
# ...                                                 ...
# 1612  https://www.bbcgoodfood.com/recipes/1911/flavo...
# 1613  https://www.bbcgoodfood.com/recipes/3248/crisp...
# 1614  https://www.bbcgoodfood.com/recipes/3047/smoke...
# 1615  https://www.bbcgoodfood.com/recipes/1797/spicy...
# 1616  https://www.bbcgoodfood.com/recipes/3250/sage-...
#
#                                             Ingredients
# 0     [2 tbsp olive oil, knob butter, 1 onion, finel...
# 1     [175g butter, chopped, 200g dark muscovado sug...
# 2     [200g dark muscovado sugar, 175g butter, chopp...
# 3     [500g strong white flour, plus extra for dusti...
# 4     [280g self-raising flour, 175g golden caster s...
# ...                                                 ...
# 1612  [100g softened butter, 2-3 tbsp chopped fresh ...
# 1613  [3 medium-sized duckss (each about 2¼kg/5lb), ...
# 1614  [300g basmati rice, 8 eggs, 400g pack sliced s...
# 1615  [6 x 250g pkts unsalted butter, 2 tsp hot chil...
# 1616  [all the innards, wings and bones from the duc...
#
# [1617 rows x 3 columns]

# %%
#establish connection to MongoDB via pymongo:
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
#create the recipes_db database:
db = client.recipes_db

#create the collections within the recipes_db database:
recipe = db.recipe
main = db.main
side = db.side
dessert = db.dessert

# %%
#drop the collection to clear out any data that may have been from a previous connection:
db.recipe.drop()

#convert the dataframe containing recipe names, urls, and ingredients into a JSON file and store it into a records variable:
records = json.loads(filtered_recipe_df.T.to_json()).values()

#insert the JSON into the recipe collection:
db.recipe.insert_many(records)

# %%
#drop the collection to clear out any data that may have been from a previous connection:
db.main.drop()

#insert the dictionary of main dish items into the main collection:
db.main.insert_one(main_dict)

# %%
#drop the collection to clear out any data that may have been from a previous connection:
db.side.drop()

#insert the dictionary of side dish items into the side collection:
db.side.insert_one(side_dict)

# %%
#drop the collection to clear out any data that may have been from a previous connection:
db.dessert.drop()

#insert the dictionary of dessert items into the dessert collection:
db.dessert.insert_one(dessert_dict)

# %%
results =  recipe.find({ "Ingredients": {"$regex": "chicken"}})
for result in results:
    print(f" You should try {result['Name']}, at {result['url']}")
# Out:
#  You should try Christmas pie, at https://www.bbcgoodfood.com/recipes/2793/christmas-pie
#  You should try Orange-stuffed Christmas duck, at https://www.bbcgoodfood.com/recipes/orange-stuffed-christmas-duck
#  You should try Gravy for the Christmas turkey, at https://www.bbcgoodfood.com/recipes/893639/gravy-for-the-christmas-turkey
#  You should try Easy Christmas turkey, at https://www.bbcgoodfood.com/recipes/cheats-christmas-turkey-red-cabbage-wedges
#  You should try Christmas goose with root veg, sticky pears & bramble gravy, at https://www.bbcgoodfood.com/recipes/76606/christmas-goose-with-root-veg-sticky-pears-and-bra
#  You should try Ham, leek & potato pie, at https://www.bbcgoodfood.com/recipes/8812/ham-leek-and-potato-pie
#  You should try Sticky Port gravy, at https://www.bbcgoodfood.com/recipes/sticky-port-gravy
#  You should try Sweet potato & butternut squash soup with lemon & garlic toast, at https://www.bbcgoodfood.com/recipes/sweet-potato-butternut-squash-soup-lemon-garlic-toast
#  You should try Chestnut, bacon & parsnip soup, at https://www.bbcgoodfood.com/recipes/chestnut-bacon-parsnip-soup
#  You should try Mini chicken fajitas, at https://www.bbcgoodfood.com/recipes/mini-chicken-fajitas
#  You should try Chestnut & wild mushroom stuffed three-bird roast, at https://www.bbcgoodfood.com/recipes/chestnut-wild-mushroom-stuffed-three-bird-roast
#  You should try Spicy satay wings with peanut sauce, at https://www.bbcgoodfood.com/recipes/spicy-satay-wings-peanut-sauce
#  You should try Fig & pancetta American stuffing, at https://www.bbcgoodfood.com/recipes/fig-pancetta-american-stuffing
#  You should try Turkey ramen, at https://www.bbcgoodfood.com/recipes/turkey-ramen
#  You should try Ham, turkey & sprout pie, at https://www.bbcgoodfood.com/recipes/ham-turkey-sprout-pie
#  You should try Roast guinea fowl with chestnut, sage & lemon stuffing, at https://www.bbcgoodfood.com/recipes/2807666/roast-guinea-fowl-with-chestnut-sage-and-lemon-stu
#  You should try Duck & pork terrine with cranberries & pistachios, at https://www.bbcgoodfood.com/recipes/8202/duck-and-pork-terrine-with-cranberries-and-pistach
#  You should try Date & red wine sauce, at https://www.bbcgoodfood.com/recipes/2429/date-and-red-wine-sauce-
#  You should try Mustard chicken with winter vegetables, at https://www.bbcgoodfood.com/recipes/8199/mustard-chicken-with-winter-vegetables
#  You should try Turkey crown with roast garlic & pancetta, at https://www.bbcgoodfood.com/recipes/1788639/italianstyle-turkey-crown-with-roast-garlic-and-pa
#  You should try Slow-cooked duck legs in Port with celeriac gratin, at https://www.bbcgoodfood.com/recipes/2778661/slowcooked-duck-legs-in-port-with-celeriac-gratin
#  You should try Quick braised cabbage with pancetta, at https://www.bbcgoodfood.com/recipes/8211/quick-braised-cabbage-with-pancetta
#  You should try Polenta & pancetta stuffing, at https://www.bbcgoodfood.com/recipes/890650/polenta-and-pancetta-stuffing
#  You should try Chicken tagine with spiced Brussels sprouts & feta, at https://www.bbcgoodfood.com/recipes/chicken-tagine-spiced-brussels-feta
#  You should try Easy red wine gravy, at https://www.bbcgoodfood.com/recipes/3042/easy-red-wine-gravy
#  You should try Make-ahead gravy, at https://www.bbcgoodfood.com/recipes/2743668/makeahead-gravy
#  You should try Leftover turkey casserole, at https://www.bbcgoodfood.com/recipes/1826709/leftover-turkey-casserole-
#  You should try Braised chestnuts, apples & Brussels sprouts, at https://www.bbcgoodfood.com/recipes/braised-chestnuts-apples-brussels-sprouts
#  You should try Creamy lemon, pancetta & rosemary turkey, at https://www.bbcgoodfood.com/recipes/4985/creamy-lemon-pancetta-and-rosemary-turkey
#  You should try Mixed greens with walnuts, at https://www.bbcgoodfood.com/recipes/146616/mixed-greens-with-walnuts-
#  You should try Slow cooker turkey breasts with wine & bacon, at https://www.bbcgoodfood.com/recipes/slow-cooker-turkey-breasts-wine-bacon
#  You should try Cider roast turkey, at https://www.bbcgoodfood.com/recipes/4960/cider-roast-turkey
#  You should try Cranberry-topped raised pie, at https://www.bbcgoodfood.com/recipes/cranberry-topped-raised-pie
#  You should try Faux gras with toast & pickles, at https://www.bbcgoodfood.com/recipes/faux-gras-toast-pickles
#  You should try One-pot partridge with drunken potatoes, at https://www.bbcgoodfood.com/recipes/one-pot-partridge-drunken-potatoes
#  You should try Slow-cooked goose with cranberry salsa, at https://www.bbcgoodfood.com/recipes/slow-cooked-goose-cranberry-salsa
#  You should try Turkey noodle soup, at https://www.bbcgoodfood.com/recipes/988633/turkey-noodle-soup
#  You should try Red wine risotto with duck & garlicky mushrooms, at https://www.bbcgoodfood.com/recipes/8814/red-wine-risotto-with-duck-and-garlicky-mushrooms
#  You should try Carrot & star anise purée, at https://www.bbcgoodfood.com/recipes/893649/carrot-and-star-anise-pure
#  You should try Classic roast goose with cider gravy, at https://www.bbcgoodfood.com/recipes/8764/classic-roast-goose-with-cider-gravy
#  You should try Creamy celery gratin, at https://www.bbcgoodfood.com/recipes/8818/creamy-celery-gratin
#  You should try Venison & wild mushroom Wellington, at https://www.bbcgoodfood.com/recipes/76604/venison-and-wild-mushroom-wellington
#  You should try Pancetta-wrapped turkey breast with herby lemon & pine nut stuffing, at https://www.bbcgoodfood.com/recipes/5040/pancettawrapped-turkey-breast-with-herby-lemon-and
#  You should try Roast duck two ways with spiced clementine sauce, at https://www.bbcgoodfood.com/recipes/8263/roast-duck-two-ways-with-spiced-clementine-sauce
#  You should try Fruity turkey tagine, at https://www.bbcgoodfood.com/recipes/fruity-turkey-tagine
#  You should try Four & twenty chicken & ham pie, at https://www.bbcgoodfood.com/recipes/2762678/four-and-twenty-chicken-and-ham-pie
#  You should try Sticky pork & pineapple hotpot, at https://www.bbcgoodfood.com/recipes/sticky-pork-pineapple-hotpot
#  You should try Chicken liver parfait with sultanas & raisins, at https://www.bbcgoodfood.com/recipes/72601/chicken-liver-parfait-with-sultanas-and-raisins
#  You should try Buttered peas & leeks, at https://www.bbcgoodfood.com/recipes/893651/buttered-peas-and-leeks
#  You should try Salt & pepper turkey, at https://www.bbcgoodfood.com/recipes/2179/salt-and-pepper-turkey
#  You should try Roast potato, turkey, sausage & stuffing pie, at https://www.bbcgoodfood.com/recipes/roast-potato-turkey-sausage-stuffing-pie
#  You should try Buttered sprouts with pancetta, at https://www.bbcgoodfood.com/recipes/3193/buttered-sprouts-with-pancetta
#  You should try Butter-roasted supreme of chicken with wild mushroom & potato gratin, at https://www.bbcgoodfood.com/recipes/887649/butterroasted-supreme-of-chicken-with-wild-mushroo
#  You should try Madeira gravy, at https://www.bbcgoodfood.com/recipes/8361/madeira-gravy
#  You should try Citrus & thyme turkey, at https://www.bbcgoodfood.com/recipes/2289/citrus-and-thyme-turkey
#  You should try Wild rice, chestnut & squash stuffing, at https://www.bbcgoodfood.com/recipes/890657/wild-rice-chestnut-and-squash-stuffing
#  You should try Chicken liver & mushroom nests, at https://www.bbcgoodfood.com/recipes/72612/chicken-liver-and-mushroom-nests
#  You should try Bay & bacon roast turkey with make-ahead gravy, at https://www.bbcgoodfood.com/recipes/bay-bacon-roast-turkey-make-ahead-gravy
#  You should try Roast lamb stuffed with apricot & mint, at https://www.bbcgoodfood.com/recipes/roast-lamb-stuffed-apricot-mint
#  You should try Silky chicken liver parfait tart, at https://www.bbcgoodfood.com/recipes/8153/silky-chicken-liver-parfait-tart
#  You should try Golden stuffed goose, at https://www.bbcgoodfood.com/recipes/2298/golden-stuffed-goose
#  You should try Turkey minestrone, at https://www.bbcgoodfood.com/recipes/turkey-minestrone
#  You should try Spiced red cabbage with prunes, at https://www.bbcgoodfood.com/recipes/8369/spiced-red-cabbage-with-prunes
#  You should try Roast turkey & cranberry Wellington, at https://www.bbcgoodfood.com/recipes/1083/roast-turkey-and-cranberry-wellington
#  You should try Tasty make-ahead gravy, at https://www.bbcgoodfood.com/recipes/tasty-make-ahead-gravy
#  You should try Sticky bourbon BBQ wings with blue cheese dip, at https://www.bbcgoodfood.com/recipes/sticky-bourbon-bbq-wings-blue-cheese-dip
#  You should try Roast turkey with pecan, sausage & chestnut stuffing & roast shallots, at https://www.bbcgoodfood.com/recipes/1788640/roast-turkey-with-pecan-sausage-and-chestnut-stuff
#  You should try Scandinavian roast turkey with prune & juniper stuffing & caramelised apples, at https://www.bbcgoodfood.com/recipes/1788638/scandinavian-roast-turkey-with-prune-and-juniper-s
#  You should try Make-ahead Prosecco & wild mushroom gravy, at https://www.bbcgoodfood.com/recipes/make-ahead-prosecco-wild-mushroom-gravy
#  You should try Duck with red cabbage & madeira gravy, at https://www.bbcgoodfood.com/recipes/2297/duck-with-red-cabbage-and-madeira-gravy
#  You should try Partridge in cider with apples & celery, at https://www.bbcgoodfood.com/recipes/partridge-cider-apples-celery
#  You should try Roast turkey with sage & onion butter and Marsala gravy, at https://www.bbcgoodfood.com/recipes/995640/roast-turkey-with-sage-and-onion-butter-and-marsal
#  You should try Game terrine, at https://www.bbcgoodfood.com/recipes/2656636/game-terrine
#  You should try Chicken terrine with leeks & apricots, at https://www.bbcgoodfood.com/recipes/chicken-terrine-leeks-apricots
#  You should try Bay & orange roast turkey, at https://www.bbcgoodfood.com/recipes/146612/bay-and-orange-roast-turkey
#  You should try Truffled Jerusalem artichoke soup, at https://www.bbcgoodfood.com/recipes/truffled-jerusalem-artichoke-soup
#  You should try Chicken liver pâté, at https://www.bbcgoodfood.com/recipes/chicken-liver-pate
#  You should try Creamy chicken & mango curry, at https://www.bbcgoodfood.com/recipes/2762671/creamy-chicken-and-mango-curry
#  You should try Cumin-spiced roast chicken with pork & pistachio stuffing, at https://www.bbcgoodfood.com/recipes/cumin-spiced-roast-chicken-pork-pistachio-stuffing
#  You should try Turkey & chestnut gravy, at https://www.bbcgoodfood.com/recipes/turkey-chestnut-gravy
#  You should try Turkey Bánh mì, at https://www.bbcgoodfood.com/recipes/turkey-banh-mi
#  You should try Chip shop curry sauce, at https://www.bbcgoodfood.com/recipes/chip-shop-curry-sauce
#  You should try Proper turkey gravy, at https://www.bbcgoodfood.com/recipes/1837662/proper-turkey-gravy
#  You should try Homemade gravy, at https://www.bbcgoodfood.com/recipes/2831667/homemade-gravy
#  You should try Creamy smoked salmon, leek & potato soup, at https://www.bbcgoodfood.com/recipes/890642/creamy-smoked-salmon-leek-and-potato-soup
#  You should try Lemon & honey chicken, at https://www.bbcgoodfood.com/recipes/1979/lemon-and-honey-chicken
#  You should try Sticky pork with cranberries, at https://www.bbcgoodfood.com/recipes/1039640/sticky-pork-with-cranberries
#  You should try Spiced parsnip & ham soup, at https://www.bbcgoodfood.com/recipes/886634/spiced-parsnip-and-ham-soup
#  You should try Spaghetti with walnuts, raisins & parsley, at https://www.bbcgoodfood.com/recipes/1022644/spaghetti-with-walnuts-raisins-and-parsley
#  You should try Baked buffalo chicken wings, at https://www.bbcgoodfood.com/recipes/1803651/baked-buffalo-chicken-wings
#  You should try Ham with boozy cranberry & mushroom sauce, at https://www.bbcgoodfood.com/recipes/1149/ham-with-boozy-cranberry-and-mushroom-sauce
#  You should try Saffron roast turkey, at https://www.bbcgoodfood.com/recipes/5033/saffron-roast-turkey
#  You should try Perky turkey soup, at https://www.bbcgoodfood.com/recipes/1378/perky-turkey-soup
#  You should try Broccoli soup with cheese toasties, at https://www.bbcgoodfood.com/recipes/1039638/broccoli-soup-with-cheese-toasties
#  You should try Canapés & cocktails, at https://www.bbcgoodfood.com/recipes/147613/canaps-and-cocktails
#  You should try Herby fondant potatoes, at https://www.bbcgoodfood.com/recipes/2767666/herby-fondant-potatoes
#  You should try Festive stuffed chicken, at https://www.bbcgoodfood.com/recipes/festive-stuffed-chicken
#  You should try Thai turkey filo dippers, at https://www.bbcgoodfood.com/recipes/thai-turkey-filo-dippers
#  You should try Mustard-glazed roast chicken with Waldorf stuffing, at https://www.bbcgoodfood.com/recipes/2530636/mustardglazed-roast-chicken-with-waldorf-stuffing
#  You should try Jumbo turkey samosas, at https://www.bbcgoodfood.com/recipes/jumbo-turkey-samosas
#  You should try Ham & veg crumble, at https://www.bbcgoodfood.com/recipes/ham-veg-crumble
#  You should try Orange & spice wings, at https://www.bbcgoodfood.com/recipes/orange-spice-wings
#  You should try Herb-studded roast loin of pork with apple & cider gravy, at https://www.bbcgoodfood.com/recipes/2806662/herbstudded-roast-loin-of-pork-with-apple-and-cide
#  You should try Turkey laksa, at https://www.bbcgoodfood.com/recipes/1267659/turkey-laksa
#  You should try Silky celeriac soup with smoked haddock, at https://www.bbcgoodfood.com/recipes/75601/silky-celeriac-soup-with-smoked-haddock
#  You should try Slow roast honey & sesame duck, at https://www.bbcgoodfood.com/recipes/2968/slow-roast-honey-and-sesame-duck
#  You should try Velvety duck liver parfait, at https://www.bbcgoodfood.com/recipes/4971/velvety-duck-liver-parfait
#  You should try Coronation turkey with homemade chapattis, at https://www.bbcgoodfood.com/recipes/146609/coronation-turkey-with-homemade-chapattis
#  You should try Next level turkey & ham pie, at https://www.bbcgoodfood.com/recipes/ham-turkey-pie
#  You should try Three-in-one braised vegetables, at https://www.bbcgoodfood.com/recipes/5030/threeinone-braised-vegetables
#  You should try Celeriac soup with scallops & black pudding, at https://www.bbcgoodfood.com/recipes/1805650/celeriac-soup-with-scallops-and-black-pudding
#  You should try Moroccan-spiced turkey pie, at https://www.bbcgoodfood.com/recipes/moroccan-spiced-turkey-pie
#  You should try Moist turkey crown with chestnut truffle stuffing, at https://www.bbcgoodfood.com/recipes/5039/moist-turkey-crown-with-chestnut-truffle-stuffing
#  You should try Herb-buttered turkey, roasties & cranberry sauce gravy, at https://www.bbcgoodfood.com/recipes/3189/herbbuttered-turkey-roasties-and-cranberry-sauce-g
#  You should try Cranberry chicken salad, at https://www.bbcgoodfood.com/recipes/884634/cranberry-chicken-salad
#  You should try Chicken, kale & sprout stir-fry, at https://www.bbcgoodfood.com/recipes/chicken-kale-sprout-stir-fry
#  You should try Grilled baby onions with cream & basil, at https://www.bbcgoodfood.com/recipes/749716/grilled-baby-onions-with-cream-and-basil
#  You should try Korean rice pot, at https://www.bbcgoodfood.com/recipes/1813659/korean-rice-pot
#  You should try Slow-roasted pork shoulder with leeks, apricots & thyme, at https://www.bbcgoodfood.com/recipes/2604640/slowroasted-pork-shoulder-with-leeks-apricots-and-
#  You should try Celeriac & parsnip bake, at https://www.bbcgoodfood.com/recipes/celeriac-parsnip-bake
#  You should try Winter cannellini bean soup, at https://www.bbcgoodfood.com/recipes/1148/winter-cannellini-bean-soup
#  You should try Chicken liver & raisin pâté, at https://www.bbcgoodfood.com/recipes/166624/chicken-liver-and-raisin-pt
#  You should try Healthy gravy, at https://www.bbcgoodfood.com/recipes/healthy-turkey-gravy
#  You should try Mustard-buttered chicken with tarragon, peas & carrots, at https://www.bbcgoodfood.com/recipes/5910/mustardbuttered-chicken-with-tarragon-peas-and-car
#  You should try Easy coq au vin, at https://www.bbcgoodfood.com/recipes/3176/coq-au-vin
#  You should try Partridge with wine & cinnamon, at https://www.bbcgoodfood.com/recipes/4808/partridge-with-wine-and-cinnamon
#  You should try Lemony potato gratin, at https://www.bbcgoodfood.com/recipes/lemony-potato-gratin
#  You should try Roast chicken with savoury sauce, at https://www.bbcgoodfood.com/recipes/2299/roast-chicken-with-savoury-sauce
#  You should try Poule au pot with stuffing balls & garlic cream, at https://www.bbcgoodfood.com/recipes/997640/poule-au-pot-with-stuffing-balls-and-garlic-cream
#  You should try Smoked salmon kedgeree, at https://www.bbcgoodfood.com/recipes/3047/smoked-salmon-kedgeree

# %%
results =  recipe.find({ "Name": {"$regex": "cookies"}})
for result in results:
    print(f" You should try {result['Name']}, at {result['url']}")
# Out:
#  You should try Sparkling vanilla Christmas cookies, at https://www.bbcgoodfood.com/recipes/2798/sparkling-vanilla-christmas-cookies
#  You should try Pistachio & cranberry cookies, at https://www.bbcgoodfood.com/recipes/1759655/pistachio-and-cranberry-cookies
#  You should try Macadamia & cranberry American cookies, at https://www.bbcgoodfood.com/recipes/13387/macadamia-and-cranberry-american-cookies
#  You should try Little almond cookies, at https://www.bbcgoodfood.com/recipes/73616/little-almond-cookies
#  You should try Coconut & cinnamon place-name cookies, at https://www.bbcgoodfood.com/recipes/1826698/coconut-and-cinnamon-placename-cookies
#  You should try Honey & spice cookies, at https://www.bbcgoodfood.com/recipes/honey-spice-cookies
#  You should try Clove sugar cookies, at https://www.bbcgoodfood.com/recipes/1758667/clove-sugar-cookies
#  You should try Fortune cookies, at https://www.bbcgoodfood.com/recipes/fortune-cookies

# %%
maindishes=list(main.find())
d = 0

for dish in maindishes:
    #print("dish: ", dish["Main"])
    for d in range(0,6):
        results0 =  recipe.find({ "Name": {"$regex": dish["Main"][d] }})
        d += 1
        for result in results0:
            print(f" You should try {result['Name']}, at {result['url']}")
# Out:
#  You should try Turkey ramen, at https://www.bbcgoodfood.com/recipes/turkey-ramen
#  You should try Turkey, thyme & leek meatloaf, at https://www.bbcgoodfood.com/recipes/3010/turkey-thyme-and-leek-meatloaf
#  You should try Turkey crown with roast garlic & pancetta, at https://www.bbcgoodfood.com/recipes/1788639/italianstyle-turkey-crown-with-roast-garlic-and-pa
#  You should try Turkey, brie & cranberry Wellington, at https://www.bbcgoodfood.com/recipes/2830673/turkey-brie-and-cranberry-wellington
#  You should try Turkey curry, at https://www.bbcgoodfood.com/recipes/turkey-potato-curry
#  You should try Turkey cacciatore with a twist, at https://www.bbcgoodfood.com/recipes/1826693/turkey-cacciatore-with-a-twist
#  You should try Turkey noodle soup, at https://www.bbcgoodfood.com/recipes/988633/turkey-noodle-soup
#  You should try Turkey tonnato salad, at https://www.bbcgoodfood.com/recipes/8815/turkey-tonnato-salad
#  You should try Turkey minestrone, at https://www.bbcgoodfood.com/recipes/turkey-minestrone
#  You should try Turkey bubble & squeak, at https://www.bbcgoodfood.com/recipes/turkey-bubble-squeak
#  You should try Turkey, bacon & chorizo bombe, at https://www.bbcgoodfood.com/recipes/turkey-bacon-chorizo-bombe
#  You should try Turkey & chestnut gravy, at https://www.bbcgoodfood.com/recipes/turkey-chestnut-gravy
#  You should try Turkey Bánh mì, at https://www.bbcgoodfood.com/recipes/turkey-banh-mi
#  You should try Turkey laksa, at https://www.bbcgoodfood.com/recipes/1267659/turkey-laksa
#  You should try Turkey & parsnip curry, at https://www.bbcgoodfood.com/recipes/1380/turkey-and-parsnip-curry
#  You should try Chicken tagine with spiced Brussels sprouts & feta, at https://www.bbcgoodfood.com/recipes/chicken-tagine-spiced-brussels-feta
#  You should try Chicken liver parfait with sultanas & raisins, at https://www.bbcgoodfood.com/recipes/72601/chicken-liver-parfait-with-sultanas-and-raisins
#  You should try Chicken liver & mushroom nests, at https://www.bbcgoodfood.com/recipes/72612/chicken-liver-and-mushroom-nests
#  You should try Chicken terrine with leeks & apricots, at https://www.bbcgoodfood.com/recipes/chicken-terrine-leeks-apricots
#  You should try Chicken liver pâté, at https://www.bbcgoodfood.com/recipes/chicken-liver-pate
#  You should try Chicken, kale & sprout stir-fry, at https://www.bbcgoodfood.com/recipes/chicken-kale-sprout-stir-fry
#  You should try Chicken liver & raisin pâté, at https://www.bbcgoodfood.com/recipes/166624/chicken-liver-and-raisin-pt

# %%
sidedishes=list(side.find())
x = 0

for dish in sidedishes:
    #print("dish: ", dish["Main"])
    for x in range(0,12):
        results1 =  recipe.find({ "Name": {"$regex": dish["Side"][x] }})
        x += 1
        for result in results1:
            print(f" You should try {result['Name']}, at {result['url']}")
# Out:
#  You should try Carrots with pine nuts, raisins & parsley, at https://www.bbcgoodfood.com/recipes/2751667/carrots-with-pine-nuts-raisins-and-parsley
#  You should try Cauliflower, chestnut & sage cake, at https://www.bbcgoodfood.com/recipes/cauliflower-chestnut-sage-cake
#  You should try Cauliflower cakes with green yogurt sauce, at https://www.bbcgoodfood.com/recipes/cauliflower-cakes-green-yogurt-sauce
#  You should try Cauliflower cheese rolls, at https://www.bbcgoodfood.com/recipes/cauliflower-cheese-rolls
#  You should try Cauliflower & carrot salad, at https://www.bbcgoodfood.com/recipes/8201/cauliflower-and-carrot-salad
#  You should try Cauliflower cheese with walnuts & crumbs, at https://www.bbcgoodfood.com/recipes/cauliflower-cheese-walnuts-crumbs
#  You should try Cauliflower & onion cream, at https://www.bbcgoodfood.com/recipes/2561/cauliflower-and-onion-cream
#  You should try Cauliflower & chestnut soup, at https://www.bbcgoodfood.com/recipes/cauliflower-chestnut-soup
#  You should try Cauliflower, rice & lentil salad, at https://www.bbcgoodfood.com/recipes/2766666/cauliflower-rice-and-lentil-salad
#  You should try Corn cups with prawns, mango & chillies, at https://www.bbcgoodfood.com/recipes/corn-cups-prawns-mango-chillies
#  You should try Green beans with shallots, at https://www.bbcgoodfood.com/recipes/1272638/green-beans-with-shallots
#  You should try Green beans with wholegrain mustard, at https://www.bbcgoodfood.com/recipes/green-beans-wholegrain-mustard
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-234-d6d649d213df> in <module>
#       5     #print("dish: ", dish["Main"])
#       6     for x in range(0,12):
# ----> 7         results1 =  recipe.find({ "Name": {"$regex": dish["Side"][x] }})
#       8         x += 1
#       9         for result in results1:
#
# IndexError: list index out of range

# %%
dessertdishes=list(dessert.find())
y = 0


for dish in dessertdishes:
    #print("dish: ", dish["Main"])
    for y in range(0,10):
        results3 =  recipe.find({ "Name": {"$regex": dish["Dessert"][y] }})
        y += 1
        for result in results3:
            print(f" You should try {result['Name']}, at {result['url']}")
# Out:
#  You should try Ice cream bombe, at https://www.bbcgoodfood.com/recipes/ice-cream-bombe
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-235-01245d1db6ce> in <module>
#       6     #print("dish: ", dish["Main"])
#       7     for y in range(0,10):
# ----> 8         results3 =  recipe.find({ "Name": {"$regex": dish["Dessert"][y] }})
#       9         y += 1
#      10         for result in results3:
#
# IndexError: list index out of range

# %%
y=0
x=0
d=0
